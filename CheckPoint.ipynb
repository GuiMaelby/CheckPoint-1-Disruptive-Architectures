# %% [markdown]
# ## Aprendizagem de máquina
#
# ### Objetivos
#
#   - Avaliar os conceitos de aprendizado de maquina aprendidos no curso

# %% [markdown]
# # Desafio
#
# Você foi contratado por uma empresa inovadora do ramo imobiliario como `QuintoAndar, Loft, Terraz, grupo Zap (ZAP, Viva Real, DataZAP, FipeZAP, SuaHouse, Geoimóvel, Sub100 e Conecta Imobi) ou Imobi Conference`. O seu desafio está no apio à tomada de decisão baseada em dados (empresa data driven).
#
# Nesse sentido, use a base de dados **aptos.csv** para realizar a descoberta do conhecimento e responder a pergunta:
#
# **`Quanto vale um apartamento de 72m2 com 2 quartos, 2 vagas, reformado no Centro?`**

# %% [markdown]
# ### Orientações
#
# Siga as instruções, completando e construindo os algoritmos necessários.
#
# Nas celulas` Seu Código aqui...` significa que é necessário realizar a implementação de algum código. Utilize quantos blocos(células) julgar necessário para criar o código.
#
# Nas celulas `Responda` significa que é nessário uma resposta clara e objetiva (pode ser por texto, código, gráfico, imagem...) para a pergunta.

# %% [markdown]
# ## Rubrica para avaliação
#
# Os critérios de avaliação do projeto segue conforme a rubrica.
#
# - R1: Exploração de Dados (Até 2 pontos)
# - R2: Análise Descritiva de Dados (Até 2 pontos)
# - R3: Desenvolvimento do Modelo (Até 2 pontos)
# - R4: Treinamento e Teste do Modelo (Até 2 pontos)
# - R5: Conclusões Finais (Até 2 pontos)
#
# **Nota_final = R1 + R2 + R3 + R4 + R5**

# %% [markdown]
# # 1. Exploração de Dados
#
# Carregue o dataset e faça uma inspeção nas 15 primeiras linhas para identificação básica dos atributos.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
df = pd.read_csv("/content/aptos.csv")

print(df)
# Out:
#      metros  valor  quartos  vagas  reformado          bairro
# 0       107  560.0        3      2        0.0  Vila Lusitania
# 1       107  555.0        3      2        1.0  Vila Lusitania
# 2        49  196.0        2      1        0.0    Ferrazopolis
# 3       104  515.0        3      2        1.0          Centro
# 4        92  560.0        3      2        1.0  Vila Lusitania
# ..      ...    ...      ...    ...        ...             ...
# 109      65  340.0        2      2        1.0          Centro
# 110      56  247.0        2      1        0.0        Planalto
# 111     126  736.0        3      3        0.0           Iraja
# 112      96  560.0        3      1        0.0          Centro
# 113     103  667.0        3      3        0.0     Baeta Neves
#
# [114 rows x 6 columns]

# %%
df.head(15)
# Out:
#     metros  valor  quartos  vagas  reformado          bairro
# 0      107  560.0        3      2        0.0  Vila Lusitania
# 1      107  555.0        3      2        1.0  Vila Lusitania
# 2       49  196.0        2      1        0.0    Ferrazopolis
# 3      104  515.0        3      2        1.0          Centro
# 4       92  560.0        3      2        1.0  Vila Lusitania
# 5       51  249.0        2      1        0.0          Taboao
# 6      140  635.0        4      3        1.0          Centro
# 7       50  210.0        2      1        1.0        Demarchi
# 8       93  450.0        3      2        0.0     Baeta Neves
# 9      107  425.0        3      2        1.0     Rudge Ramos
# 10     100  422.0        3      2        1.0     Baeta Neves
# 11      64  250.0        2      1        1.0       Pauliceia
# 12      65  350.0        2      2        1.0          Centro
# 13      71  303.0        3      1        0.0          Centro
# 14      64  294.0        3      1        0.0        Planalto

# %% [markdown]
# ### `Pergunta:` Apresente uma breve descrição do significado de cada atributo:
#
# Exemplo:
# - Idade: Idade em anos da pessoa
# - Marca: fabricante de carros
# - Combustivel: tipo de combustível (gasolina, disel...)
# - Especie: Tipo de flor iris-setosa, virginica... (Variável Alvo)

# %% [markdown]
# **Resposta:**
#
# -   Metros: Tamanho do apartamento
# -   Valor: Valor do apartamento
# -   Quartos: Quantidade de quartos no apartamento
# -   Vagas: Vagas na garagem disponivel para o dono do apartamento
# -   Reformado: Se o apartamento está reformado ou não
# -   Bairro: Localização do apartamento

# %% [markdown]
# **Pergunta:** Cite 2 cenários que podem fazer sentido na leitura dos dados apresentados.
#
# Exemplo:
# - Eu acho que o preço da gasolina sobe com o preço do petróleo.
# - Eu acho que na média homens são mais altos que mulheres na mesma faixa etaria.

# %% [markdown]
# **Resposta:**
#
# 1.  Talvez a Vila Lusitana tenha a maior média entre os bairros na questão do tamanho dos apartamentos
# 2.  Acredito que o Centro seja o bairro com tipos de apartamento mais diversos em relação a tamanho e preço.

# %% [markdown]
# ## 2. Análise descritiva de dados
#
# Faça uma análise exploratória dos dados. Utilize-se de gráficos e tabelas auxiliares, faça correlações entre os atributos.... Com o objetivo validar as afirmações levantadas acima.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.pairplot(df, hue='bairro', height=4)
plt.show()

# %%
g = sns.violinplot(y='bairro', x='valor', data=df, inner='quartile')
plt.show()

# %%
g = sns.violinplot(y='bairro', x='metros', data=df, inner='quartile')
plt.show()

# %% [markdown]
# ### __(BONUS: 1 ponto extra.)__ Análise de Outliers
# *Esse é um ponto extra, faça se quiser...
#
# Realize a análise e o tratamento de **outliers**, como referência para estudo:
#
# * [link1](https://machinelearningmastery.com/model-based-outlier-detection-and-removal-in-python/)
# * [link2](https://towardsdatascience.com/4-machine-learning-techniques-for-outlier-detection-in-python-21e9cfacb81d)
# * [link3](https://minerandodados.com.br/tratando-outliers-python/)
#
# **Pergunta:** Foram localizados outliers? Qual o método de análise adotado? Se existe, como os dados foram tratados (foram removidos ou mantidos)?

# %% [markdown]
# ## 3. Desenvolvimento do Modelo

# %% [markdown]
# **Pergunta:** O conjunto de dados indica a aplicação de qual modelo de aprendizagem de maquina para determinação do valor de um imóvel? Por que ?

# %% [markdown]
# **Resposta:**
#
#     [ ] Aprendizado por reforço
#     [x] Aprendizado supervisionado
#     [ ] Aprendizado não supervisionado
#
#     Porque os dados já estão rotuládos

# %% [markdown]
# **Pergunta:** Qual a técnica sugerida para este projeto?

# %% [markdown]
# **Resposta:**
#
#     [x] Regressão
#     [ ] Classificação
#     [ ] Clusterização
#
#     Porque é estatístico

# %% [markdown]
# **Pergunta:** Escolha 2 modelos de algoritmos para testar a performance de cada um deles.

# %% [markdown]
# **Resposta:**
#
# 1. Regressão Linear
# 2. Árvores de decisão

# %% [markdown]
# __(BONUS: 1 ponto extra.)__ **Pergunta:** Explique como cada algoritmo funciona.

# %% [markdown]
# **Resposta:**
#
# 1. Tenta buscar relações entre os dados
# 2. Árvore de decisão ajuda a dividir os dados

# %% [markdown]
# ## 4. Treinamento e teste do modelo

# %% [markdown]
# Crie um subset dos dados apenas com os atributos que serão utilizados para o treinameno e teste do modelo. Divida o subset em conjunto de treinamento e teste.

# %%
subset = df.loc[:, ['metros', 'quartos', 'valor']]

print(subset)
# Out:
#      metros  quartos  valor
# 0       107        3  560.0
# 1       107        3  555.0
# 2        49        2  196.0
# 3       104        3  515.0
# 4        92        3  560.0
# ..      ...      ...    ...
# 109      65        2  340.0
# 110      56        2  247.0
# 111     126        3  736.0
# 112      96        3  560.0
# 113     103        3  667.0
#
# [114 rows x 3 columns]

# %% [markdown]
# Faça o treinamento e teste dos 2 algoritmos escolhidos. Utilize uma métrica (ex. R2-score, RMSE e MAE...) para avaliar a performance dos modelos.

# %% [markdown]
# ### Algoritmo 1

# %%
X = df[['metros', 'quartos']]

Y = df['valor']  

print(f"Formato das tabelas de dados {X.shape} e saidas {Y.shape}")
# Out:
# Formato das tabelas de dados (114, 2) e saidas (114,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

X_treino, X_teste, Y_treino, Y_teste = train_test_split(X, Y, test_size=0.2)

print(X_treino.shape)
print(X_teste.shape)
print(Y_treino.shape)
print(Y_teste.shape)
# Out:
# (91, 2)
# (23, 2)
# (91,)
# (23,)

# %%
X_treino.head()
# Out:
#     metros  quartos
# 44      56        2
# 95      88        3
# 82      86        3
# 84      52        2
# 3      104        3

# %%
Y_treino.head()
# Out:
# 44    249.0
# 95    520.0
# 82    460.0
# 84    272.0
# 3     515.0
# Name: valor, dtype: float64

# %%
lin_model = LinearRegression()

lin_model.fit(X_treino, Y_treino)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-b4d9970aba87> in <module>
#       1 lin_model = LinearRegression()
#       2
# ----> 3 lin_model.fit(X_treino, Y_treino)
#
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     646         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     647
# --> 648         X, y = self._validate_data(
#     649             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650         )
#
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
#     585             out = X, y
#     586
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1120     )
#    1121
# -> 1122     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1123
#    1124     check_consistent_length(X, y)
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py in _check_y(y, multi_output, y_numeric, estimator)
#    1130     """Isolated part of check_X_y dedicated to y validation"""
#    1131     if multi_output:
# -> 1132         y = check_array(
#    1133             y,
#    1134             accept_sparse="csr",
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     919
#     920         if force_all_finite:
# --> 921             _assert_all_finite(
#     922                 array,
#     923                 input_name=input_name,
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     159                 "#estimators-that-handle-nan-values"
#     160             )
# --> 161         raise ValueError(msg_err)
#     162
#     163
#
# ValueError: Input y contains NaN.

# %%
y_teste_predito = lin_model.predict(X_teste)
print("Predição usando regressão, retorna valores continuos: {}".format(y_teste_predito))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-c6286f361df3> in <module>
# ----> 1 y_teste_predito = lin_model.predict(X_teste)
#       2 print("Predição usando regressão, retorna valores continuos: {}".format(y_teste_predito))
#
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     352             Returns predicted values.
#     353         """
# --> 354         return self._decision_function(X)
#     355
#     356     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     336
#     337         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
# --> 338         return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     339
#     340     def predict(self, X):
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'

# %%
plt.scatter(Y_teste,y_teste_predito)
plt.xlabel('Valor Real')
plt.ylabel('Valor Predito')
# Out:
# Text(0, 0.5, 'Valor Predito')

# %%
from sklearn.metrics import r2_score, mean_squared_error,mean_absolute_error
import numpy as np

print("Soma dos Erros ao Quadrado (SSE): %2.f " % np.sum((y_teste_predito - Y_teste)**2))
print("Erro Quadrático Médio (MSE): %.2f" % mean_squared_error(Y_teste, y_teste_predito))
print("Erro Médio Absoluto (MAE): %.2f" % mean_absolute_error(Y_teste, y_teste_predito))
print ("Raiz do Erro Quadrático Médio (RMSE): %.2f " % np.sqrt(mean_squared_error(Y_teste, y_teste_predito)))
print("R2-score: %.2f" % r2_score(y_teste_predito , Y_teste) )
# Out:
# Soma dos Erros ao Quadrado (SSE): 1524366
# Erro Quadrático Médio (MSE): 66276.77
# Erro Médio Absoluto (MAE): 218.37
# Raiz do Erro Quadrático Médio (RMSE): 257.44
# R2-score: -2.30

# %% [markdown]
# ### Algoritmo 2

# %%
X = df[['metros', 'quartos']]

Y = df['valor']

# %%
from sklearn.tree import DecisionTreeRegressor

X_treino, X_teste, Y_treino, Y_teste = train_test_split(X, Y, test_size=0.2)

print(X_treino.shape)
print(X_teste.shape)
print(Y_treino.shape)
print(Y_teste.shape)
# Out:
# (91, 2)
# (23, 2)
# (91,)
# (23,)

# %%
tree_model = DecisionTreeRegressor()

tree_model.fit(X_treino, Y_treino)
# Out:
# DecisionTreeRegressor()

# %%
y_teste_predito = tree_model.predict(X_teste)
print("Predição usando regressão, retorna valores continuos: {}".format(y_teste_predito))
# Out:
# Predição usando regressão, retorna valores continuos: [535.66666667 210.4        278.5        259.         300.
#  210.4        551.         217.         251.33333333 535.66666667
#  248.         300.         331.5        307.33333333 300.
#  473.5        473.5        736.         345.         248.
#  413.         525.         200.        ]

# %%
plt.scatter(Y_teste,y_teste_predito)
plt.xlabel('Valor Real')
plt.ylabel('Valor Predito')
# Out:
# Text(0, 0.5, 'Valor Predito')

# %%
from sklearn.metrics import r2_score, mean_squared_error,mean_absolute_error
import numpy as np

print("Soma dos Erros ao Quadrado (SSE): %2.f " % np.sum((y_teste_predito - Y_teste)**2))
print("Erro Quadrático Médio (MSE): %.2f" % mean_squared_error(Y_teste, y_teste_predito))
print("Erro Médio Absoluto (MAE): %.2f" % mean_absolute_error(Y_teste, y_teste_predito))
print ("Raiz do Erro Quadrático Médio (RMSE): %.2f " % np.sqrt(mean_squared_error(Y_teste, y_teste_predito)))
print("R2-score: %.2f" % r2_score(y_teste_predito , Y_teste) )
# Out:
# Soma dos Erros ao Quadrado (SSE): 113218
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-9c6c354b1da4> in <module>
#       3
#       4 print("Soma dos Erros ao Quadrado (SSE): %2.f " % np.sum((y_teste_predito - Y_teste)**2))
# ----> 5 print("Erro Quadrático Médio (MSE): %.2f" % mean_squared_error(Y_teste, y_teste_predito))
#       6 print("Erro Médio Absoluto (MAE): %.2f" % mean_absolute_error(Y_teste, y_teste_predito))
#       7 print ("Raiz do Erro Quadrático Médio (RMSE): %.2f " % np.sqrt(mean_squared_error(Y_teste, y_teste_predito)))
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     440     0.825...
#     441     """
# --> 442     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     443         y_true, y_pred, multioutput
#     444     )
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      99     """
#     100     check_consistent_length(y_true, y_pred)
# --> 101     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     102     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     103
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     919
#     920         if force_all_finite:
# --> 921             _assert_all_finite(
#     922                 array,
#     923                 input_name=input_name,
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     159                 "#estimators-that-handle-nan-values"
#     160             )
# --> 161         raise ValueError(msg_err)
#     162
#     163
#
# ValueError: Input contains NaN.

# %% [markdown]
# Sumarize na tabela abaixo os resultados obtidos para os conjuntos de dados de treino e de teste

# %% [markdown]
# **Resposta:**
#
# |    | algoritmo1 | algoritmo2 |
# |:---:|:---:|:---:|
# | treino | X | X |
# | teste  | X | X |

# %% [markdown]
# **Pergunta:** Qual dos algoritmos obteve um resultado melhor? Justifique
#
# **Resposta:**

# %% [markdown]
# ## Modelo de produção: Teste com novos dados
#
# Use seu modelo treinado para determinar:
#
# **`Quanto vale um apartamento de 72m2 com 2 quartos, 2 vagas, reformado no Centro?`**

# %%
#Seu Código aqui...

# %% [markdown]
# ## 6. Conclusões finais
#
# Ufa!!... Chegamos ao final. Parabéns! De forma simplificada e completa, passamos por todas as etapas de um projeto de aprendizado de maquina. Outras etapas podem ser adicionadas no tratamento dos dados e desenvolvimento do modelo.

# %% [markdown]
# **Pergunta:**: O modelo desenvolvido obteve um resultado satisfatório? Justifique:
#
# **Resposta**:

# %% [markdown]
# **Pergunta:**: O que faria diferente para melhorar resultado obtido? Justifique:
#
# **Resposta**:
